# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import seaborn as sns
import matplotlib.pylab as plt
import plotly.express as px

import warnings
import copy
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('mimic3d.csv')
df.head()
# Out:
#    hadm_id gender  age  LOSdays admit_type             admit_location  \
# 0   100001      F   35     6.17  EMERGENCY  CLINIC REFERRAL/PREMATURE
# 1   100003      M   59     4.04  EMERGENCY       EMERGENCY ROOM ADMIT
# 2   100006      F   48    12.04  EMERGENCY       EMERGENCY ROOM ADMIT
# 3   100007      F   73     7.29  EMERGENCY       EMERGENCY ROOM ADMIT
# 4   100009      M   60     4.88  EMERGENCY  TRANSFER FROM HOSP/EXTRAM
#
#             AdmitDiagnosis insurance           religion marital_status  ...  \
# 0    DIABETIC KETOACIDOSIS   Private  PROTESTANT QUAKER       DIVORCED  ...
# 1           UPPER GI BLEED   Private      NOT SPECIFIED         SINGLE  ...
# 2               COPD FLARE   Private      NOT SPECIFIED         SINGLE  ...
# 3        BOWEL OBSTRUCTION   Private             JEWISH        MARRIED  ...
# 4  CORONARY ARTERY DISEASE   Private           CATHOLIC        MARRIED  ...
#
#   NumMicroLabs  NumNotes  NumOutput  NumRx NumProcEvents  NumTransfers  \
# 0         0.65      0.05       5.19  14.91          1.13          0.65
# 1         1.24      1.59       5.45   7.18          0.99          1.24
# 2         0.33      0.15       4.15   6.23          0.00          0.33
# 3         0.69      0.17       9.05  11.52          0.00          0.96
# 4         0.61      0.34      16.19  25.00          2.87          2.05
#
#    NumChartEvents  ExpiredHospital  TotalNumInteract  LOSgroupNum
# 0          398.70                0            493.89            1
# 1          373.02                0            465.71            1
# 2          286.21                0            344.00            3
# 3          526.06                0            603.05            1
# 4          554.92                0            679.84            1
#
# [5 rows x 28 columns]

# %%
df_clean = copy.deepcopy(df)

#df_clean['marital_status_unknown'] = np.where((df['marital_status']=="UNKNOWN"), True, False)
#df_clean['AdmitDiagnosis'] = np.where((df['AdmitDiagnosis'].isna()), "NOT SPECIFIED", df_clean['AdmitDiagnosis'])

# %%
df_clean['ethnicity'] = np.where(df_clean['ethnicity'].str.contains("HISPANIC/LATINO"), "HISPANIC OR LATINO", df_clean['ethnicity'])
df_clean['ethnicity'] = np.where(df_clean['ethnicity'].str.contains("ASIAN -"), "ASIAN", df_clean['ethnicity'])
df_clean['ethnicity'] = np.where(df_clean['ethnicity'].str.contains("WHITE - "), "WHITE", df_clean['ethnicity'])
df_clean['ethnicity'] = np.where(df_clean['ethnicity'].str.contains("BLACK"), "BLACK", df_clean['ethnicity'])
df_clean['ethnicity'] = np.where(df_clean['ethnicity'].str.contains("PORTUGUESE"), "WHITE", df_clean['ethnicity'])
df_clean['ethnicity'] = np.where(df_clean['ethnicity'].str.contains("SOUTH AMERICAN"), "MULTI RACE ETHNICITY", df_clean['ethnicity'])
df_clean['ethnicity'] = np.where(df_clean['ethnicity'].str.contains("CARIBBEAN ISLAND"), "MULTI RACE ETHNICITY", df_clean['ethnicity'])
df_clean['ethnicity'] = np.where(df_clean['ethnicity'].str.contains("PACIFIC ISLANDER"), "PACIFIC ISLANDER", df_clean['ethnicity'])
df_clean['ethnicity'] = np.where(df_clean['ethnicity'].str.contains("UNABLE TO OBTAIN"), "UNKNOWN/NOT SPECIFIED", df_clean['ethnicity'])
df_clean['ethnicity'] = np.where(df_clean['ethnicity'].str.contains("PATIENT DECLINED TO ANSWER"), "UNKNOWN/NOT SPECIFIED", df_clean['ethnicity'])
df_clean['ethnicity'] = np.where(df_clean['ethnicity'].str.contains("AMERICAN INDIAN/ALASKA NATIVE"), "AMERICAN INDIAN/ALASKA NATIVE", df_clean['ethnicity'])

# %%
df_clean['marital_status'] = np.where(df_clean['marital_status'].str.contains("UNKNOWN "), "UNKNOWN", df_clean['marital_status'])
df_clean['marital_status'] = np.where((df['marital_status'].isna()) & (df['age'] <= 18), "SINGLE", df_clean['marital_status'])
df_clean['marital_status'] = np.where((df['marital_status'].isna()) , "UNKNOWN", df_clean['marital_status'])

# %%
df_clean['religion'] = np.where((df_clean['religion'].isna()), "UNKNOWN", df_clean['religion'])
df_clean['religion'] = np.where((df_clean['religion'] == "UNOBTAINABLE"), "UNKNOWN", df_clean['religion'])
df_clean['religion'] = np.where((df_clean['religion'] == "NOT SPECIFIED"), "UNKNOWN", df_clean['religion'])

# %%
df_clean['age_g'] = np.where((df_clean['age'] <= 2), 0, df_clean['age'])
df_clean['age_g'] = np.where((df_clean['age'] <= 5)& (df_clean['age'] > 2), 1, df_clean['age_g'])
df_clean['age_g'] = np.where((df_clean['age'] <= 13)& (df_clean['age'] > 5), 2, df_clean['age_g'])
df_clean['age_g'] = np.where((df_clean['age'] <= 18)& (df_clean['age'] > 13), 3, df_clean['age_g'])
df_clean['age_g'] = np.where((df_clean['age'] <= 33)& (df_clean['age'] > 18), 4, df_clean['age_g'])
df_clean['age_g'] = np.where((df_clean['age'] <= 48)& (df_clean['age'] > 33), 5, df_clean['age_g'])
df_clean['age_g'] = np.where((df_clean['age'] <= 64)& (df_clean['age'] > 48), 6, df_clean['age_g'])
df_clean['age_g'] = np.where((df_clean['age'] <= 78)& (df_clean['age'] > 64), 7, df_clean['age_g'])
df_clean['age_g'] = np.where((df_clean['age'] >  78), 8, df_clean['age_g'])

df_clean.head()
# Out:
#    hadm_id gender  age  LOSdays admit_type             admit_location  \
# 0   100001      F   35     6.17  EMERGENCY  CLINIC REFERRAL/PREMATURE
# 1   100003      M   59     4.04  EMERGENCY       EMERGENCY ROOM ADMIT
# 2   100006      F   48    12.04  EMERGENCY       EMERGENCY ROOM ADMIT
# 3   100007      F   73     7.29  EMERGENCY       EMERGENCY ROOM ADMIT
# 4   100009      M   60     4.88  EMERGENCY  TRANSFER FROM HOSP/EXTRAM
#
#             AdmitDiagnosis insurance           religion marital_status  ...  \
# 0    DIABETIC KETOACIDOSIS   Private  PROTESTANT QUAKER       DIVORCED  ...
# 1           UPPER GI BLEED   Private            UNKNOWN         SINGLE  ...
# 2               COPD FLARE   Private            UNKNOWN         SINGLE  ...
# 3        BOWEL OBSTRUCTION   Private             JEWISH        MARRIED  ...
# 4  CORONARY ARTERY DISEASE   Private           CATHOLIC        MARRIED  ...
#
#   NumNotes  NumOutput  NumRx  NumProcEvents NumTransfers  NumChartEvents  \
# 0     0.05       5.19  14.91           1.13         0.65          398.70
# 1     1.59       5.45   7.18           0.99         1.24          373.02
# 2     0.15       4.15   6.23           0.00         0.33          286.21
# 3     0.17       9.05  11.52           0.00         0.96          526.06
# 4     0.34      16.19  25.00           2.87         2.05          554.92
#
#    ExpiredHospital  TotalNumInteract  LOSgroupNum  age_g
# 0              0.0            493.89          1.0      5
# 1              0.0            465.71          1.0      6
# 2              0.0            344.00          3.0      5
# 3              0.0            603.05          1.0      7
# 4              0.0            679.84          1.0      6
#
# [5 rows x 29 columns]

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## diagnosis cleaning

# %%
df = pd.read_excel('ICD10.xlsx')
df.head()
# Out:
#     CODE            SHORT DESCRIPTION (VALID ICD-10 FY2023)  \
# 0   A000  Cholera due to Vibrio cholerae 01, biovar chol...
# 1   A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 2   A009                               Cholera, unspecified
# 3  A0100                         Typhoid fever, unspecified
# 4  A0101                                 Typhoid meningitis
#
#               LONG DESCRIPTION (VALID ICD-10 FY2023) NF EXCL
# 0  Cholera due to Vibrio cholerae 01, biovar chol...     NaN
# 1    Cholera due to Vibrio cholerae 01, biovar eltor     NaN
# 2                               Cholera, unspecified     NaN
# 3                         Typhoid fever, unspecified     NaN
# 4                                 Typhoid meningitis     NaN

# %%
df['Group'] = np.where(df['CODE'].str.startswith("A"), "Infections and parasitic diseases", df['CODE'])
df['Group'] = np.where(df['CODE'].str.startswith("B"), "Infections and parasitic diseases", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("C"), "Neoplasms", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("D"), "Neoplasms, Blood, Blood-forming Organs", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("E"), "Endocrine, Nutritional, Metabolic", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("F"), "Mental and Behavioral Disorders", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("G"), "Nervous System", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("H"), "Eye and Adnexa, Ear and Mastoid Process", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("I"), "Circulatory System", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("J"), "Respiratory System", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("K"), "Digestive System", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("L"), "Skin and Subcutaneous Tissue", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("M"), "Musculoskeletal and Connective Tissue", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("N"), "Genitourinary System", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("O"), "Pregnancy, Childbirth, and Puerperium", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("P"), "Certain Conditions Originating in the Perinatal Period", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("Q"), "Congenital Malformations, Deformations and Chromosomal Abnormalities", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("R"), "Symptoms, Signs and Abnormal Clinical and Lab Findings", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("S"), "Injury, Poisoning, Certain Other Consequences of External Causes", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("T"), "Injury, Poisoning, Certain Other Consequences of External Causes", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("U"), "U", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("V"), "External Causes of Morbidity", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("W"), "External Causes of Morbidity", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("X"), "External Causes of Morbidity", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("Y"), "External Causes of Morbidity", df['Group'])
df['Group'] = np.where(df['CODE'].str.startswith("Z"), "Factors influencing health status and contact with health services", df['Group'])

# %%
df =df.drop([ 'SHORT DESCRIPTION (VALID ICD-10 FY2023)', 'NF EXCL'], axis=1)
df.head()
# Out:
#     CODE             LONG DESCRIPTION (VALID ICD-10 FY2023)  \
# 0   A000  Cholera due to Vibrio cholerae 01, biovar chol...
# 1   A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 2   A009                               Cholera, unspecified
# 3  A0100                         Typhoid fever, unspecified
# 4  A0101                                 Typhoid meningitis
#
#                                Group
# 0  Infections and parasitic diseases
# 1  Infections and parasitic diseases
# 2  Infections and parasitic diseases
# 3  Infections and parasitic diseases
# 4  Infections and parasitic diseases

# %%
rslt_df = df[df['Group'] == "U"]
rslt_df
# Out:
#        CODE LONG DESCRIPTION (VALID ICD-10 FY2023) Group
# 65461  U070                Vaping-related disorder     U
# 65462  U071                               COVID-19     U
# 65463  U099   Post COVID-19 condition, unspecified     U

# %%
import nltk
import re

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk import word_tokenize
stop_words = set(nltk.corpus.stopwords.words('english'))
lemmatizer = nltk.stem.WordNetLemmatizer()
def doc_clean(text_content):
  if(type(text_content)== float):
    return "";
  text_content = word_tokenize(re.sub(r'[^a-zA-Z]', ' ', text_content.lower()))
  text_content = [ele for ele in text_content if ele not in stop_words]
  text_list = []
  for ele in text_content:
    ele = lemmatizer.lemmatize(ele, 'a')
    ele = lemmatizer.lemmatize(ele, 'v')
    ele = lemmatizer.lemmatize(ele, 'n')
    ele = lemmatizer.lemmatize(ele, 'r')
    ele = lemmatizer.lemmatize(ele, 's')
    text_list.append(ele)
  return(' '.join(text_list))

# %%
df["tokens"] = df.apply (lambda x: doc_clean(x["LONG DESCRIPTION (VALID ICD-10 FY2023)"]), axis=1)
df
# Out:
#         CODE             LONG DESCRIPTION (VALID ICD-10 FY2023)  \
# 0       A000  Cholera due to Vibrio cholerae 01, biovar chol...
# 1       A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 2       A009                               Cholera, unspecified
# 3      A0100                         Typhoid fever, unspecified
# 4      A0101                                 Typhoid meningitis
# ...      ...                                                ...
# 72831   Y990           Civilian activity done for income or pay
# 72832   Y991                                  Military activity
# 72833   Y992                                 Volunteer activity
# 72834   Y998                        Other external cause status
# 72835   Y999                  Unspecified external cause status
#
#                                    Group  \
# 0      Infections and parasitic diseases
# 1      Infections and parasitic diseases
# 2      Infections and parasitic diseases
# 3      Infections and parasitic diseases
# 4      Infections and parasitic diseases
# ...                                  ...
# 72831       External Causes of Morbidity
# 72832       External Causes of Morbidity
# 72833       External Causes of Morbidity
# 72834       External Causes of Morbidity
# 72835       External Causes of Morbidity
#
#                                             tokens
# 0      cholera due vibrio cholerae biovar cholerae
# 1         cholera due vibrio cholerae biovar eltor
# 2                              cholera unspecified
# 3                        typhoid fever unspecified
# 4                               typhoid meningitis
# ...                                            ...
# 72831              civilian activity do income pay
# 72832                            military activity
# 72833                           volunteer activity
# 72834                        external cause status
# 72835            unspecified external cause status
#
# [72836 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer()
vects = vect.fit_transform(df["tokens"])

# %%
term_document_matrix = pd.DataFrame(vects.todense())
term_document_matrix.columns = vect.get_feature_names_out()
term_document_matrix = term_document_matrix.T
term_document_matrix.columns = df["Group"]
term_document_matrix = term_document_matrix.T
term_document_matrix
# Out:
#                                    ab  abandonment  abdomen  abdominal  \
# Group
# Infections and parasitic diseases   0            0        0          0
# Infections and parasitic diseases   0            0        0          0
# Infections and parasitic diseases   0            0        0          0
# Infections and parasitic diseases   0            0        0          0
# Infections and parasitic diseases   0            0        0          0
# ...                                ..          ...      ...        ...
# External Causes of Morbidity        0            0        0          0
# External Causes of Morbidity        0            0        0          0
# External Causes of Morbidity        0            0        0          0
# External Causes of Morbidity        0            0        0          0
# External Causes of Morbidity        0            0        0          0
#
#                                    abducent  abductor  abl  ablation  \
# Group
# Infections and parasitic diseases         0         0    0         0
# Infections and parasitic diseases         0         0    0         0
# Infections and parasitic diseases         0         0    0         0
# Infections and parasitic diseases         0         0    0         0
# Infections and parasitic diseases         0         0    0         0
# ...                                     ...       ...  ...       ...
# External Causes of Morbidity              0         0    0         0
# External Causes of Morbidity              0         0    0         0
# External Causes of Morbidity              0         0    0         0
# External Causes of Morbidity              0         0    0         0
# External Causes of Morbidity              0         0    0         0
#
#                                    ablative  abnormal  ...  zero  zika  zinc  \
# Group                                                  ...
# Infections and parasitic diseases         0         0  ...     0     0     0
# Infections and parasitic diseases         0         0  ...     0     0     0
# Infections and parasitic diseases         0         0  ...     0     0     0
# Infections and parasitic diseases         0         0  ...     0     0     0
# Infections and parasitic diseases         0         0  ...     0     0     0
# ...                                     ...       ...  ...   ...   ...   ...
# External Causes of Morbidity              0         0  ...     0     0     0
# External Causes of Morbidity              0         0  ...     0     0     0
# External Causes of Morbidity              0         0  ...     0     0     0
# External Causes of Morbidity              0         0  ...     0     0     0
# External Causes of Morbidity              0         0  ...     0     0     0
#
#                                    zone  zonular  zoonotic  zoster  zygomatic  \
# Group
# Infections and parasitic diseases     0        0         0       0          0
# Infections and parasitic diseases     0        0         0       0          0
# Infections and parasitic diseases     0        0         0       0          0
# Infections and parasitic diseases     0        0         0       0          0
# Infections and parasitic diseases     0        0         0       0          0
# ...                                 ...      ...       ...     ...        ...
# External Causes of Morbidity          0        0         0       0          0
# External Causes of Morbidity          0        0         0       0          0
# External Causes of Morbidity          0        0         0       0          0
# External Causes of Morbidity          0        0         0       0          0
# External Causes of Morbidity          0        0         0       0          0
#
#                                    zygomycoses  zygomycosis
# Group
# Infections and parasitic diseases            0            0
# Infections and parasitic diseases            0            0
# Infections and parasitic diseases            0            0
# Infections and parasitic diseases            0            0
# Infections and parasitic diseases            0            0
# ...                                        ...          ...
# External Causes of Morbidity                 0            0
# External Causes of Morbidity                 0            0
# External Causes of Morbidity                 0            0
# External Causes of Morbidity                 0            0
# External Causes of Morbidity                 0            0
#
# [72836 rows x 6137 columns]

# %%
#GA_prototype = term_document_matrix.sum()
G_prototypes = term_document_matrix.groupby('Group').sum()
G_prototypes
# Out:
#                                                     ab  abandonment  abdomen  \
# Group
# Certain Conditions Originating in the Perinatal...   0            0        0
# Circulatory System                                   0            0        0
# Congenital Malformations, Deformations and Chro...   0            0        0
# ab                                           0
# abandonment                                  0
# abdomen                                      0
# abdominal                                    1
# abducent                                     0
# ...                                        ...
# zoonotic                                     2
# zoster                                      11
# zygomatic                                    0
# zygomycoses                                  1
# zygomycosis                                  1
#
# Group        Injury, Poisoning, Certain Other Consequences of External Causes  \
# ab                                                           0
# abandonment                                                 12
# abdomen                                                     54
# abdominal                                                  342
# abducent                                                     9
# ...                                                        ...
# zoonotic                                                     0
# zoster                                                       0
# zygomatic                                                   18
# zygomycoses                                                  0
# zygomycosis                                                  0
#
# Group        Mental and Behavioral Disorders  \
# ab                                         0
# abandonment                                0
# abdomen                                    0
# abdominal                                  0
# abducent                                   0
# ...                                      ...
# zoonotic                                   0
# zoster                                     0
# zygomatic                                  0
# zygomycoses                                0
# zygomycosis                                0
#
# Group        Musculoskeletal and Connective Tissue  Neoplasms  \
# ab                                               0          0
# abandonment                                      0          0
# abdomen                                         10          3
# abdominal                                        0         36
# abducent                                         0          0
# ...                                            ...        ...
# zoonotic                                         0          0
# zoster                                           0          0
# zygomatic                                        0          0
# zygomycoses                                      0          0
# zygomycosis                                      0          0
#
# Group        Neoplasms, Blood, Blood-forming Organs  Nervous System  \
# ab                                                0               0
# abandonment                                       0               0
# abdomen                                           2               0
# abdominal                                         2               2
# abducent                                          0               0
# ...                                             ...             ...
# zoonotic                                          0               0
# zoster                                            0               0
# zygomatic                                         0               0
# zygomycoses                                       0               0
# zygomycosis                                       0               0
#
# Group        Pregnancy, Childbirth, and Puerperium  Respiratory System  \
# ab                                               0                   0
# abandonment                                      0                   0
# abdomen                                          0                   0
# abdominal                                       31                   0
# abducent                                         0                   0
# ...                                            ...                 ...
# zoonotic                                         0                   0
# zoster                                           0                   0
# zygomatic                                        0                   0
# zygomycoses                                      0                   0
# zygomycosis                                      0                   0
#
# Group        Skin and Subcutaneous Tissue  \
# ab                                      2
# abandonment                             0
# abdomen                                 0
# abdominal                               5
# abducent                                0
# ...                                   ...
# zoonotic                                0
# zoster                                  0
# zygomatic                               0
# zygomycoses                             0
# zygomycosis                             0
#
# Group        Symptoms, Signs and Abnormal Clinical and Lab Findings  U
# ab                                                           0       0
# abandonment                                                  0       0
# abdomen                                                      2       0
# abdominal                                                   47       0
# abducent                                                     0       0
# ...                                                        ...      ..
# zoonotic                                                     0       0
# zoster                                                       0       0
# zygomatic                                                    0       0
# zygomycoses                                                  0       0
# zygomycosis                                                  0       0
#
# [6137 rows x 20 columns]

# %%
row_sums = G_prototypes.sum(axis=1)
row_sums = np.log2(26 / row_sums).round(2)
df_multiplied = G_prototypes.mul(row_sums, axis=0)

# %%
df_multiplied = df_multiplied.T
df_multiplied
# Out:
#                                                      ab  abandonment  abdomen  \
# Group
# Certain Conditions Originating in the Perinatal...  0.0         0.00    -0.00
# Circulatory System                                  0.0         0.00    -0.00
# Congenital Malformations, Deformations and Chro...  0.0         0.00    -0.00
# Digestive System                                    0.0         0.00    -0.00
# Endocrine, Nutritional, Metabolic                   0.0         0.00    -0.00
# Symptoms, Signs and Abnormal Clinical and Lab F...     -0.00   0.00       0.0
# U                                                      -0.00   0.00       0.0
#
#                                                     ablative  abnormal  ...  \
# Group                                                                   ...
# Certain Conditions Originating in the Perinatal...       0.0    -30.50  ...
# Circulatory System                                       0.0     -0.00  ...
# Congenital Malformations, Deformations and Chro...       0.0    -18.30  ...
# Digestive System                                         0.0     -3.05  ...
# Endocrine, Nutritional, Metabolic                        0.0     -0.00  ...
# External Causes of Morbidity                             0.0    -57.95  ...
# Eye and Adnexa, Ear and Mastoid Process                  0.0    -39.65  ...
# Genitourinary System                                     4.7     -6.10  ...
# Infections and parasitic diseases                        0.0     -0.00  ...
# Injury, Poisoning, Certain Other Consequences o...       0.0     -9.15  ...
# Mental and Behavioral Disorders                          0.0     -0.00  ...
# Musculoskeletal and Connective Tissue                    0.0     -3.05  ...
# Neoplasms                                                0.0     -0.00  ...
# Neoplasms, Blood, Blood-forming Organs                   0.0     -0.00  ...
# Nervous System                                           0.0     -0.00  ...
# Pregnancy, Childbirth, and Puerperium                    0.0    -39.65  ...
# Respiratory System                                       0.0     -0.00  ...
# Skin and Subcutaneous Tissue                             0.0     -0.00  ...
# Symptoms, Signs and Abnormal Clinical and Lab F...       0.0   -448.35  ...
# U                                                        0.0     -0.00  ...
#
#                                                      zero  zika   zinc   zone  \
# Group
# Certain Conditions Originating in the Perinatal...   0.00   3.7   0.00   -0.0
# Circulatory System                                   0.00   0.0   0.00   -0.0
# Congenital Malformations, Deformations and Chro...   0.00   0.0   0.00   -0.0
# Digestive System                                     0.00   0.0   0.00   -0.0
# Endocrine, Nutritional, Metabolic                    0.00   0.0   1.78   -0.0
# External Causes of Morbidity                         0.00   0.0   0.00   -0.0
# Eye and Adnexa, Ear and Mastoid Process              0.00   0.0   0.00   -0.0
# Genitourinary System                                 0.00   0.0   0.00   -0.0
# Infections and parasitic diseases                    0.00   3.7   0.00   -0.0
# Injury, Poisoning, Certain Other Consequences o...   0.00   0.0  10.68 -111.6
# Mental and Behavioral Disorders                      0.00   0.0   0.00   -0.0
# Musculoskeletal and Connective Tissue                0.00   0.0   0.00   -0.0
# Neoplasms                                            0.00   0.0   0.00   -3.1
# Neoplasms, Blood, Blood-forming Organs              12.72   0.0   0.00   -0.0
# Nervous System                                       0.00   0.0   0.00   -0.0
# Pregnancy, Childbirth, and Puerperium                0.00   0.0   0.00   -0.0
# Respiratory System                                   0.00   0.0   0.00   -0.0
# Skin and Subcutaneous Tissue                         0.00   0.0   0.00   -0.0
# Symptoms, Signs and Abnormal Clinical and Lab F...   0.00   0.0   0.00   -3.1
# U                                                    0.00   0.0   0.00   -0.0
#
#                                                     zonular  zoonotic  zoster  \
# Group
# Certain Conditions Originating in the Perinatal...      0.0       0.0    0.00
# Circulatory System                                      0.0       0.0    0.00
# Congenital Malformations, Deformations and Chro...      0.0       0.0    0.00
# Digestive System                                        0.0       0.0    0.00
# Endocrine, Nutritional, Metabolic                       0.0       0.0    0.00
# External Causes of Morbidity                            0.0       0.0    0.00
# Eye and Adnexa, Ear and Mastoid Process                10.8       0.0    0.00
# Genitourinary System                                    0.0       0.0    0.00
# Infections and parasitic diseases                       0.0       7.4   13.64
# Injury, Poisoning, Certain Other Consequences o...      0.0       0.0    0.00
# Mental and Behavioral Disorders                         0.0       0.0    0.00
# Musculoskeletal and Connective Tissue                   0.0       0.0    0.00
# Neoplasms                                               0.0       0.0    0.00
# Neoplasms, Blood, Blood-forming Organs                  0.0       0.0    0.00
# Nervous System                                          0.0       0.0    0.00
# Pregnancy, Childbirth, and Puerperium                   0.0       0.0    0.00
# Respiratory System                                      0.0       0.0    0.00
# Skin and Subcutaneous Tissue                            0.0       0.0    0.00
# Symptoms, Signs and Abnormal Clinical and Lab F...      0.0       0.0    0.00
# U                                                       0.0       0.0    0.00
#
#                                                     zygomatic  zygomycoses  \
# Group
# Certain Conditions Originating in the Perinatal...       0.00          0.0
# Circulatory System                                       0.00          0.0
# Congenital Malformations, Deformations and Chro...       0.00          0.0
# Digestive System                                         0.00          0.0
# Endocrine, Nutritional, Metabolic                        0.00          0.0
# External Causes of Morbidity                             0.00          0.0
# Eye and Adnexa, Ear and Mastoid Process                  0.00          0.0
# Genitourinary System                                     0.00          0.0
# Infections and parasitic diseases                        0.00          4.7
# Injury, Poisoning, Certain Other Consequences o...       9.54          0.0
# Mental and Behavioral Disorders                          0.00          0.0
# Musculoskeletal and Connective Tissue                    0.00          0.0
# Neoplasms                                                0.00          0.0
# Neoplasms, Blood, Blood-forming Organs                   0.00          0.0
# Nervous System                                           0.00          0.0
# Pregnancy, Childbirth, and Puerperium                    0.00          0.0
# Respiratory System                                       0.00          0.0
# Skin and Subcutaneous Tissue                             0.00          0.0
# Symptoms, Signs and Abnormal Clinical and Lab F...       0.00          0.0
# U                                                        0.00          0.0
#
#                                                     zygomycosis
# Group
# Certain Conditions Originating in the Perinatal...          0.0
# Circulatory System                                          0.0
# Congenital Malformations, Deformations and Chro...          0.0
# Digestive System                                            0.0
# Endocrine, Nutritional, Metabolic                           0.0
# External Causes of Morbidity                                0.0
# Eye and Adnexa, Ear and Mastoid Process                     0.0
# Genitourinary System                                        0.0
# Infections and parasitic diseases                           4.7
# Injury, Poisoning, Certain Other Consequences o...          0.0
# Mental and Behavioral Disorders                             0.0
# Musculoskeletal and Connective Tissue                       0.0
# Neoplasms                                                   0.0
# Neoplasms, Blood, Blood-forming Organs                      0.0
# Nervous System                                              0.0
# Pregnancy, Childbirth, and Puerperium                       0.0
# Respiratory System                                          0.0
# Skin and Subcutaneous Tissue                                0.0
# Symptoms, Signs and Abnormal Clinical and Lab F...          0.0
# U                                                           0.0
#
# [20 rows x 6137 columns]

# %%
df_multiplied.columns
# Out:
# Index(['ab', 'abandonment', 'abdomen', 'abdominal', 'abducent', 'abductor',
#        'abl', 'ablation', 'ablative', 'abnormal',
#        ...
#        'zero', 'zika', 'zinc', 'zone', 'zonular', 'zoonotic', 'zoster',
#        'zygomatic', 'zygomycoses', 'zygomycosis'],
#       dtype='object', length=6137)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def doc_clean2(text_content):
  if(type(text_content)== float):
    return(0);
  text_content = word_tokenize(re.sub(r'[^a-zA-Z]', ' ', text_content.lower()))
  text_content = [ele for ele in text_content if ele not in stop_words]
  text_list = []
  for ele in text_content:
    ele = lemmatizer.lemmatize(ele, 'a')
    ele = lemmatizer.lemmatize(ele, 'v')
    ele = lemmatizer.lemmatize(ele, 'n')
    ele = lemmatizer.lemmatize(ele, 'r')
    ele = lemmatizer.lemmatize(ele, 's')
    text_list.append(ele)
  text_list = ''.join(text_list)
  q_vect = []
  max_termcount = 1
  for term in row_sums.index:
    term_count = text_list.count(term)
    if max_termcount < term_count:
      max_termcount = term_count
    q_vect.append(term_count*row_sums[term])
  q_vect = [i/max_termcount for i in q_vect]
  similarity_scores = cosine_similarity(df_multiplied, [q_vect]).round(5)
  most_similar_row_index = np.argmax(similarity_scores)
  return(df_multiplied.index[most_similar_row_index]);

# %%
doc_clean2("Unspecified DEPRESSION")
# Out:
# 'Genitourinary System'

# %%
df_clean["AdmitDiagnosis"][0]
# Out:
# 'DIABETIC KETOACIDOSIS'

# %%
doc_clean2(df_clean["AdmitDiagnosis"][0])
# Out:
# 'Endocrine, Nutritional, Metabolic'

# %%
df_clean["AdmitDiagGroup"] = df_clean.apply (lambda x: doc_clean2(x["AdmitDiagnosis"]), axis=1)
df_clean
# Out:
#        hadm_id gender  age  LOSdays admit_type             admit_location  \
# 0       100001      F   35     6.17  EMERGENCY  CLINIC REFERRAL/PREMATURE
# 1       100003      M   59     4.04  EMERGENCY       EMERGENCY ROOM ADMIT
# 2       100006      F   48    12.04  EMERGENCY       EMERGENCY ROOM ADMIT
# 3       100007      F   73     7.29  EMERGENCY       EMERGENCY ROOM ADMIT
# 4       100009      M   60     4.88  EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# ...        ...    ...  ...      ...        ...                        ...
# 58971   199993      M   60    24.58  EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 58972   199994      F   58     9.75  EMERGENCY       EMERGENCY ROOM ADMIT
# 58973   199995      M   23    16.75  EMERGENCY  PHYS REFERRAL/NORMAL DELI
# 58974   199998      M   69     5.88  EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 58975   199999      M   88     5.50  EMERGENCY  CLINIC REFERRAL/PREMATURE
#
#                 AdmitDiagnosis insurance           religion marital_status  \
# 0        DIABETIC KETOACIDOSIS   Private  PROTESTANT QUAKER       DIVORCED
# 1               UPPER GI BLEED   Private            UNKNOWN         SINGLE
# 2                   COPD FLARE   Private            UNKNOWN         SINGLE
# 3            BOWEL OBSTRUCTION   Private             JEWISH        MARRIED
# 4      CORONARY ARTERY DISEASE   Private           CATHOLIC        MARRIED
# ...                        ...       ...                ...            ...
# 58971  CORONARY ARTERY DISEASE   Private           CATHOLIC       DIVORCED
# 58972    MENTAL STATUS CHANGES  Medicare           CATHOLIC         SINGLE
# 58973             ROOT ABSCESS   Private  PROTESTANT QUAKER         SINGLE
# 58974  CORONARY ARTERY DISEASE  Medicare           CATHOLIC        MARRIED
# 58975                PNEUMONIA  Medicare             JEWISH        MARRIED
#
#        ... NumOutput  NumRx  NumProcEvents  NumTransfers NumChartEvents  \
# 0      ...      5.19  14.91           1.13          0.65         398.70
# 1      ...      5.45   7.18           0.99          1.24         373.02
# 2      ...      4.15   6.23           0.00          0.33         286.21
# 3      ...      9.05  11.52           0.00          0.96         526.06
# 4      ...     16.19  25.00           2.87          2.05         554.92
# ...    ...       ...    ...            ...           ...            ...
# 58971  ...     23.11   8.01           0.00          0.08        1315.46
# 58972  ...      7.90   0.00           0.00          0.31         674.05
# 58973  ...      6.27   5.79           0.00          0.36         207.10
# 58974  ...     12.24  17.69           0.00          1.02         426.87
# 58975  ...      4.73   5.82           0.55          0.73         550.36
#
#        ExpiredHospital  TotalNumInteract  LOSgroupNum  age_g  \
# 0                    0            493.89            1      5
# 1                    0            465.71            1      6
# 2                    0            344.00            3      5
# 3                    0            603.05            1      7
# 4                    0            679.84            1      6
# ...                ...               ...          ...    ...
# 58971                0           1746.31            3      6
# 58972                0            834.98            2      6
# 58973                0            261.30            3      4
# 58974                0            537.42            1      7
# 58975                0            614.59            1      8
#
#                                           AdmitDiagGroup
# 0                      Endocrine, Nutritional, Metabolic
# 1                                         Nervous System
# 2      Certain Conditions Originating in the Perinata...
# 3                                       Digestive System
# 4                                     Circulatory System
# ...                                                  ...
# 58971                                 Circulatory System
# 58972                                     Nervous System
# 58973                                   Digestive System
# 58974                                 Circulatory System
# 58975                                 Respiratory System
#
# [58976 rows x 30 columns]

# %%
from google.colab import files
df_clean.to_csv('mimic3d_v3.csv', encoding = 'utf-8-sig')
files.download('mimic3d_v3.csv')

# %% [markdown]
# # patients

# %%
df = pd.read_csv('mimic3d_v3.csv')
df.head()
# Out:
#    Unnamed: 0  hadm_id gender  age  LOSdays admit_type  \
# 0           0   100001      F   35     6.17  EMERGENCY
# 1           1   100003      M   59     4.04  EMERGENCY
# 2           2   100006      F   48    12.04  EMERGENCY
# 3           3   100007      F   73     7.29  EMERGENCY
# 4           4   100009      M   60     4.88  EMERGENCY
#
#               admit_location           AdmitDiagnosis insurance  \
# 0  CLINIC REFERRAL/PREMATURE    DIABETIC KETOACIDOSIS   Private
# 1       EMERGENCY ROOM ADMIT           UPPER GI BLEED   Private
# 2       EMERGENCY ROOM ADMIT               COPD FLARE   Private
# 3       EMERGENCY ROOM ADMIT        BOWEL OBSTRUCTION   Private
# 4  TRANSFER FROM HOSP/EXTRAM  CORONARY ARTERY DISEASE   Private
#
#             religion  ... NumOutput  NumRx  NumProcEvents  NumTransfers  \
# 0  PROTESTANT QUAKER  ...      5.19  14.91           1.13          0.65
# 1            UNKNOWN  ...      5.45   7.18           0.99          1.24
# 2            UNKNOWN  ...      4.15   6.23           0.00          0.33
# 3             JEWISH  ...      9.05  11.52           0.00          0.96
# 4           CATHOLIC  ...     16.19  25.00           2.87          2.05
#
#    NumChartEvents ExpiredHospital  TotalNumInteract  LOSgroupNum  age_g  \
# 0          398.70               0            493.89            1      5
# 1          373.02               0            465.71            1      6
# 2          286.21               0            344.00            3      5
# 3          526.06               0            603.05            1      7
# 4          554.92               0            679.84            1      6
#
#                                       AdmitDiagGroup
# 0                  Endocrine, Nutritional, Metabolic
# 1                                     Nervous System
# 2  Certain Conditions Originating in the Perinata...
# 3                                   Digestive System
# 4                                 Circulatory System
#
# [5 rows x 31 columns]

# %%
df.columns
#df['admit_type'].unique()
# Out:
# Index(['Unnamed: 0', 'hadm_id', 'gender', 'age', 'LOSdays', 'admit_type',
#        'admit_location', 'AdmitDiagnosis', 'insurance', 'religion',
#        'marital_status', 'ethnicity', 'NumCallouts', 'NumDiagnosis',
#        'NumProcs', 'AdmitProcedure', 'NumCPTevents', 'NumInput', 'NumLabs',
#        'NumMicroLabs', 'NumNotes', 'NumOutput', 'NumRx', 'NumProcEvents',
#        'NumTransfers', 'NumChartEvents', 'ExpiredHospital', 'TotalNumInteract',
#        'LOSgroupNum', 'age_g', 'AdmitDiagGroup'],
#       dtype='object')

# %%
pf = pd.read_csv('Patient.csv')
#pf.head()

# %%
pf['age_g'] = np.where((pf['Age'] <= 2), 0, pf['Age'])
pf['age_g'] = np.where((pf['Age'] <= 5)& (pf['Age'] > 2), 1, pf['age_g'])
pf['age_g'] = np.where((pf['Age'] <= 13)& (pf['Age'] > 5), 2, pf['age_g'])
pf['age_g'] = np.where((pf['Age'] <= 18)& (pf['Age'] > 13), 3, pf['age_g'])
pf['age_g'] = np.where((pf['Age'] <= 33)& (pf['Age'] > 18), 4, pf['age_g'])
pf['age_g'] = np.where((pf['Age'] <= 48)& (pf['Age'] > 33), 5, pf['age_g'])
pf['age_g'] = np.where((pf['Age'] <= 64)& (pf['Age'] > 48), 6, pf['age_g'])
pf['age_g'] = np.where((pf['Age'] <= 78)& (pf['Age'] > 64), 7, pf['age_g'])
pf['age_g'] = np.where((pf['Age'] >  78), 8, pf['age_g'])

pf['Gender'] = np.where((pf['Gender'] == "Male"), 0, 1)
pf['Previous admission'] = np.where((pf['Previous admission'] == "No"), 0, 1)
pf['Inpatient/outpatient']	= np.where((pf['Inpatient/outpatient'] == "Inpatient"), 1, 0)
pf['Close_dist'] = np.where((pf['Location/distance'] <= 5), 1, 0)

pf['Income'] = np.where((pf['Income'] == "Low"), 1/3, pf['Income'])
pf['Income'] = np.where((pf['Income'] == "Medium"), 2/3, pf['Income'])
pf['Income'] = np.where((pf['Income'] == "High"), 3/3, pf['Income'])

pf['LOSgroupNum'] = np.where((pf['Length of Stay'] <= 4), 0, pf['Length of Stay'])
pf['LOSgroupNum'] = np.where((pf['Length of Stay'] <= 8) & (pf['Length of Stay'] > 4), 1, pf['LOSgroupNum'])
pf['LOSgroupNum'] = np.where((pf['Length of Stay'] <= 12) & (pf['Length of Stay'] > 8), 2, pf['LOSgroupNum'])
pf['LOSgroupNum'] = np.where((pf['Length of Stay'] > 12), 8, pf['LOSgroupNum'])

# %%
pf["AdmitDiagGroup"] = pf.apply (lambda x: doc_clean2(x["Diagnosis"]), axis=1)

# %%
pf['Height_bins'] = pd.qcut(pf['Height'], q=10, precision=0)
pf['Height_bin_val'] = pf.groupby("Height_bins")['Height'].transform("mean")

# %%
pf.columns
pf
# Out:
#                       Horodateur  Age  Height  Weight  Gender  \
# 0   2023/06/05 10:47:32 PM UTC−4   10  149.86      32       1
# 1   2023/06/05 10:53:15 PM UTC−4   21  172.00      55       1
# 2   2023/06/05 11:03:37 PM UTC−4   13  145.00      43       0
# 3   2023/06/05 11:09:01 PM UTC−4   55  170.00     150       0
# 4   2023/06/05 11:13:51 PM UTC−4   22  183.00     180       0
# ..                           ...  ...     ...     ...     ...
# 56  2023/06/06 12:19:04 PM UTC−4   23  175.00      68       1
# 57  2023/06/06 12:19:07 PM UTC−4   65  180.00      76       0
# 58  2023/06/06 12:44:37 PM UTC−4   70  165.00      58       1
# 59  2023/06/06 12:47:47 PM UTC−4   50  180.00      90       0
# 60  2023/06/06 12:58:10 PM UTC−4   25  170.00      70       1
#
#                     Diagnosis Marital Status    Income  Length of Stay  \
# 0                      Asthma         Single  0.333333            0.08
# 1                  Depression         Single  0.333333            2.40
# 2                Hypertension         Single  0.333333           24.00
# 3                      Asthma        Married  0.666667            0.20
# 4                    Dementia         Single  0.333333            0.20
# ..                        ...            ...       ...             ...
# 56               Appendicitis         Single  0.666667            0.30
# 57               Hypertension        Married  0.666667            0.25
# 58                     Cancer       Divorced  0.666667           10.00
# 59  Gastrointestinal Bleeding        Married  0.666667            5.00
# 60                     Cancer         Single  0.666667            3.00
#
#     Location/distance  ...  Severity of injuries Condition at discharge  \
# 0                 5.0  ...  Non-life Threatening                 Stable
# 1                 3.0  ...      Life-threatening                 Stable
# 2                12.0  ...           Superficial                 Stable
# 3                 5.0  ...  Non-life Threatening                 Stable
# 4                 8.0  ...                Severe               Improved
# ..                ...  ...                   ...                    ...
# 56                5.0  ...           Superficial                 Stable
# 57               12.0  ...                Severe                 Stable
# 58               37.0  ...                Severe              Unchanged
# 59                4.0  ...      Life-threatening                 Stable
# 60                3.0  ...                Severe                 Stable
#
#     Admission Type  Blood types age_g Close_dist LOSgroupNum  \
# 0         Elective            A     2          1         0.0
# 1         Elective            O     4          1         0.0
# 2         Elective  RH-positive     2          0         8.0
# 3        Emergency            O     6          1         0.0
# 4         Elective            B     4          0         0.0
# ..             ...          ...   ...        ...         ...
# 56          Urgent            B     4          1         0.0
# 57       Emergency            O     7          0         0.0
# 58          Urgent           AB     7          0         2.0
# 59       Emergency            B     6          1         1.0
# 60       Emergency           AB     4          1         0.0
#
#                                        AdmitDiagGroup     Height_bins  \
# 0                                  Respiratory System    (1.0, 150.0]
# 1               Pregnancy, Childbirth, and Puerperium  (170.0, 173.0]
# 2                                  Circulatory System    (1.0, 150.0]
# 3                                  Respiratory System  (165.0, 170.0]
# 4                     Mental and Behavioral Disorders  (180.0, 185.0]
# ..                                                ...             ...
# 56  Injury, Poisoning, Certain Other Consequences ...  (173.0, 177.0]
# 57                                 Circulatory System  (179.0, 180.0]
# 58  Symptoms, Signs and Abnormal Clinical and Lab ...  (160.0, 165.0]
# 59                                   Digestive System  (179.0, 180.0]
# 60  Symptoms, Signs and Abnormal Clinical and Lab ...  (165.0, 170.0]
#
#     Height_bin_val
# 0       111.354286
# 1       172.333333
# 2       111.354286
# 3       169.625000
# 4       183.333333
# ..             ...
# 56      175.750000
# 57      180.000000
# 58      163.666667
# 59      180.000000
# 60      169.625000
#
# [61 rows x 24 columns]

# %%
from google.colab import files
pf.to_csv('patients_clean.csv', encoding = 'utf-8-sig')
files.download('patients_clean.csv')

# %% [markdown]
# ## temp

# %%
pf['Cost of stay'].hist(bins=20)
# Out:
# <Axes: >

# %%
pf['Diagnosis'].unique()
# Out:
# array(['Asthma', 'Depression', 'Hypertension', 'Dementia', 'Appendicitis',
#        'Fractured Hip', 'Stroke', 'Diabetes Mellitus', 'Anxiety Disorder',
#        'Cancer', 'Osteoarthritis', 'Pneumonia', 'Schizophrenia',
#        'Gastrointestinal Bleeding'], dtype=object)

# %%
doc_clean2("Osteoarthritis")
# Out:
# 'Musculoskeletal and Connective Tissue'

# %%
pf.loc[(pf['Location/distance'] <= 5)].count()

# %% [markdown]
# # Bayesian Linear Regression

# %%
pip install pymc3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymc3 in /usr/local/lib/python3.10/dist-packages (3.11.5)
# Requirement already satisfied: arviz>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from pymc3) (0.12.1)
# Requirement already satisfied: cachetools>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from pymc3) (5.3.0)
# Requirement already satisfied: deprecat in /usr/local/lib/python3.10/dist-packages (from pymc3) (2.1.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from pymc3) (0.3.6)
# Requirement already satisfied: fastprogress>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from pymc3) (1.0.3)
# Requirement already satisfied: numpy<1.22.2,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from pymc3) (1.22.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from pymc3) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from pymc3) (0.5.3)
# Requirement already satisfied: scipy<1.8.0,>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from pymc3) (1.7.3)
# Requirement already satisfied: semver>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from pymc3) (3.0.1)
# Requirement already satisfied: theano-pymc==1.1.2 in /usr/local/lib/python3.10/dist-packages (from pymc3) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from pymc3) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from theano-pymc==1.1.2->pymc3) (3.12.0)
# Requirement already satisfied: setuptools>=38.4 in /usr/local/lib/python3.10/dist-packages (from arviz>=0.11.0->pymc3) (67.7.2)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.10/dist-packages (from arviz>=0.11.0->pymc3) (3.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from arviz>=0.11.0->pymc3) (23.1)
# Requirement already satisfied: xarray>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from arviz>=0.11.0->pymc3) (2022.12.0)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.10/dist-packages (from arviz>=0.11.0->pymc3) (1.6.4)
# Requirement already satisfied: xarray-einstats>=0.2 in /usr/local/lib/python3.10/dist-packages (from arviz>=0.11.0->pymc3) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->pymc3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->pymc3) (2022.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->pymc3) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecat->pymc3) (1.14.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (3.0.9)
# Requirement already satisfied: cftime in /usr/local/lib/python3.10/dist-packages (from netcdf4->arviz>=0.11.0->pymc3) (1.6.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from netcdf4->arviz>=0.11.0->pymc3) (2022.12.7)

# %% [markdown]
# # ________________________________________________________________________________________________________________________________________________________________

# %%
pip install dython

# %%
from dython.nominal import associations
from dython.nominal import identify_nominal_columns

categorical_features=identify_nominal_columns(df_clean)
complete_correlation= associations(df_clean, filename= 'complete_correlation.png', figsize=(30,30))['corr']
